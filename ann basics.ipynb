# %%
import numpy as npB
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('BankCustomers.csv',index_col=1)
dataset  = dataset.drop(axis=1,columns = ['RowNumber'])
dataset.head(10)
# Out:
#              Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# CustomerId
# 15634602    Hargrave          619    France  Female   42       2       0.00
# 15647311        Hill          608     Spain  Female   41       1   83807.86
# 15619304        Onio          502    France  Female   42       8  159660.80
# 15701354        Boni          699    France  Female   39       1       0.00
# 15737888    Mitchell          850     Spain  Female   43       2  125510.82
# 15574012         Chu          645     Spain    Male   44       8  113755.78
# 15592531    Bartlett          822    France    Male   50       7       0.00
# 15656148      Obinna          376   Germany  Female   29       4  115046.74
# 15792365          He          501    France    Male   44       4  142051.07
# 15592389          H?          684    France    Male   27       2  134603.88
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
dataset['Geography'] = encoder.fit_transform(dataset['Geography'])

# %%
from sklearn.preprocessing import LabelBinarizer
binarizer = LabelBinarizer()
dataset['Gender'] = binarizer.fit_transform(dataset['Gender'])
dataset['Gender']
# Out:
# CustomerId
# 15634602    0
# 15647311    0
# 15619304    0
# 15701354    0
# 15737888    0
# 15574012    1
# 15592531    1
# 15656148    0
# 15792365    1
# 15592389    1
# 15767821    1
# 15737173    1
# 15632264    0
# 15691483    0
# 15600882    0
# 15643966    1
# 15737452    1
# 15788218    0
# 15661507    1
# 15568982    0
# 15577657    1
# 15597945    0
# 15699309    0
# 15725737    1
# 15625047    0
# 15738191    1
# 15736816    1
# 15700772    1
# 15728693    0
# 15656300    1
#            ..
# 15587133    1
# 15721377    0
# 15747927    1
# 15806455    1
# 15695474    1
# 15666295    1
# 15656062    0
# 15579969    0
# 15703563    1
# 15692664    0
# 15719276    1
# 15672754    1
# 15768163    0
# 15656710    1
# 15696175    1
# 15586914    1
# 15581736    1
# 15588839    1
# 15589329    1
# 15605622    1
# 15798964    1
# 15769959    0
# 15657105    1
# 15569266    1
# 15719294    0
# 15606229    1
# 15569892    1
# 15584532    0
# 15682355    1
# 15628319    0
# ...

# %%
x = dataset.iloc[:,1:-1]
y = dataset.iloc[:,-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5203302b75fb> in <module>
# ----> 1 x = dataset.iloc[:,1:-1]
#       2 y = dataset.iloc[:,-1]
#       3 x
#
# NameError: name 'dataset' is not defined

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.25,random_state=101)

# %%
xtrain.shape
# Out:
# (7500, 10)

# %% [raw]
# import keras
# from keras.models import Sequential
# from keras.layers import Dense

# %%
BATCH_SIZE = 100
SHAPE = xtrain.shape[1]

# %%
classifier = Sequential()
classifier.add(Dense(activation="relu", input_shape=(SHAPE,),units=SHAPE, kernel_initializer="uniform"))
classifier.add(Dense(activation="relu", units=6, kernel_initializer="uniform"))
classifier.add(Dense(activation="sigmoid", units=1, kernel_initializer="uniform"))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(xtrain, ytrain, batch_size = BATCH_SIZE, epochs = 100)
# Out:
# WARNING:tensorflow:From C:\Users\aaddh\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 7500/7500 [==============================] - 0s 60us/step - loss: 0.5607 - accuracy: 0.7761
# Epoch 2/100
# 7500/7500 [==============================] - 0s 14us/step - loss: 0.5277 - accuracy: 0.7984
# Epoch 3/100
# 7500/7500 [==============================] - 0s 12us/step - loss: 0.5234 - accuracy: 0.7984
# Epoch 4/100
# 7500/7500 [==============================] - 0s 11us/step - loss: 0.5123 - accuracy: 0.7984
# Epoch 5/100
# 7500/7500 [==============================] - 0s 10us/step - loss: 0.5059 - accuracy: 0.7984
# Epoch 6/100
# 7500/7500 [==============================] - 0s 10us/step - loss: 0.5121 - accuracy: 0.7984
# Epoch 7/100
# ...

# %%
y_pred = classifier.predict(xtest)
y_pred = (y_pred>0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9bfc3f03c0a9> in <module>
# ----> 1 y_pred = classifier.predict(xtest)
#       2 y_pred = (y_pred>.5)
#
# NameError: name 'classifier' is not defined

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(ytest, y_pred)
accuracy=accuracy_score(ytest,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-4bee22ed2567> in <module>
#       1 from sklearn.metrics import confusion_matrix,accuracy_score
# ----> 2 cm = confusion_matrix(ytest, y_pred)
#       3 accuracy=accuracy_score(ytest,y_pred)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ...
